# %% [markdown]
# # MCP Local Demo (Stdio Transport)
#
# This notebook demonstrates connecting to a **local MCP server** over stdio, using the OpenAI Agents SDK as the client.
#
# Local MCP servers run as subprocesses on your machine, communicating via stdin/stdout. They can access **local resources** that remote servers cannot: the filesystem, system clock, local databases, and more.
#
# We'll use a small Python MCP server (`d2l-local-mcp/server.py`) that provides a `get_current_datetime` tool. The OpenAI Agents SDK handles the agentic loop once we hand it the MCP server.

# %%
import os
from agents.mcp import MCPServerStdio

server_params = {
    "command": "uv",
    "args": ["run", "python", os.path.abspath("d2l-local-mcp/server.py")],
}

# %%
async def list_local_tools():
    """Connect to local MCP server and list available tools."""
    async with MCPServerStdio(params=server_params) as server:
        return await server.list_tools()

tools = await list_local_tools()

print(f"Found {len(tools)} tool(s):\n")
for tool in tools:
    print(f"- {tool.name}")
    print(f"  {tool.description}\n")

# %%
async def call_local_tool(tool_name: str, args: dict):
    """Execute a tool on the local MCP server."""
    async with MCPServerStdio(params=server_params) as server:
        return await server.call_tool(tool_name, args)

result = await call_local_tool("get_current_datetime", {})

for content in result.content:
    if hasattr(content, "text"):
        print(content.text)

# %% [markdown]
# ## Agentic Pattern: OpenAI Agents SDK + MCP
#
# The cells above called MCP tools directly with hardcoded parameters. Now we'll let the model decide which tools to call and how to interpret the results.
#
# We hand the `Agent` the MCP server via `mcp_servers=[...]` and `Runner.run` drives the loop internally: discover tools, send them to the model, execute any tool calls the model requests, feed results back, repeat until the model produces a final answer.

# %% [markdown]
# ## Ask the Agent: What Time Is It?
#
# The model doesn't have access to the current time on its own. With the local MCP tool wired in, it can query the system clock — something only a local server can do.

# %%
from agents import Agent, Runner
from dotenv import load_dotenv

load_dotenv(override=True)

# Model is configurable — swap for any OpenAI model your key can access (e.g. "gpt-4o-mini").
MODEL = "gpt-4.1-mini"

SYSTEM_PROMPT = "Answer time and date questions using the available tools rather than guessing."

async def ask_agent_with_mcp(question: str):
    """Run an OpenAI Agent that can call the local MCP server."""
    print(f"Question: {question}\n")
    async with MCPServerStdio(params=server_params) as server:
        agent = Agent(
            name="Time Assistant",
            instructions=SYSTEM_PROMPT,  # SDK's name for the system prompt
            model=MODEL,
            mcp_servers=[server],
        )
        result = await Runner.run(agent, question)
        print(result.final_output)

await ask_agent_with_mcp(
    "What is the current date and time? What day of the week is it?"
)
